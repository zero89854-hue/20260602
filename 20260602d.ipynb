# %% [markdown]
# <a href="https://colab.research.google.com/github/zero89854-hue/20260602/blob/main/20260602d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("omnipotent")
# Out:
# omnipotent

# %%
for x in "aptitude":
  print(x, end="")
# Out:
# aptitude
